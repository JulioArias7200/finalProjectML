# %%
import pandas as pd
import os
import glob

# Buscar todos los archivos .sav en la carpeta actual
archivos_sav = glob.glob('*.sav')

#for archivo in archivos_sav:
    # Crear el nombre del nuevo archivo cambiando la extensión a .csv
    archivo_csv = archivo.replace('.sav', '.csv')
    
    print(f"Convirtiendo {archivo}...")
    
    # Leer y convertir
    df = pd.read_spss(archivo)
    df.to_csv(archivo_csv, index=False)

print("¡Todas las conversiones han finalizado!")
# Out:
# Convirtiendo EDSA2023_HistorialHijos.sav...
# Convirtiendo EDSA2023_HistorialParidad.sav...
# Convirtiendo EDSA2023_Hogar.sav...
# Convirtiendo EDSA2023_Hombre.sav...
# Convirtiendo EDSA2023_Mujer.sav...
# Convirtiendo EDSA2023_MujerCalendario.sav...
# Convirtiendo EDSA2023_Peso_talla_hemo.sav...
# Convirtiendo EDSA2023_PrimeraInfancia.sav...
# Convirtiendo EDSA2023_Vivienda.sav...
# ¡Todas las conversiones han finalizado!
